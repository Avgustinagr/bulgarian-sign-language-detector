# %%
import numpy as np
import pandas as pd
import cv2
import os

# %%
FREQ = 5

# %% [markdown]
# # Bulgarian Sign Language Detector #
# ## Data Collection ##
# ⚠️ <b>DON'T RUN </b>, THE VIDEOS ARE NOT IN THE REPO/ZIP (can be accessed through <a href='https://drive.google.com/drive/folders/101l61bluVN9f49zUGeR_AVPxk6osSpeX?usp=sharing'>this link</a> if needed)<br/><br/>
# I could not find any dataset that contains Bulgarian sign language so I decided to create one.
# The raw sources are videos in which people are doing the signs. Every folder contains letter videos made by the same person (1 video = 1 letter; 1 folder = letters done by the same person). Most of them have used the same source to learn the signs from, however, even so, variations are present. One of the people (vid2) has used a different source and their signs vary more, espcially when it comes to angles.

# %% [markdown]
# Make sure you're at the root folder of the project

# %%
pwd
# Out:
# '/home/avgustina/personal/AICourse/Machine Learning/Project/Final Project/Project'

# %% [markdown]
# ### Creating data folder structure ###

# %% [markdown]
# Creating a data folder with a subfolder for each letter

# %%
rm -rf data

# %%
mkdir data

# %% [markdown]
# This feels barbaric but for the sake of reproducability:

# %%
bg_alphabet = ['A','B', 'V', 'G', 'D', 'E', 'J', 'Z', 'I', 'Ik', 'K', 'L', 'M', 'N', 'O', 'P', 'R', 'S', 'T', 'U', 'F', 'H', 'C', 'CH', 'SH', 'SHt', 'Y', 'Yrm', 'YU', 'YA']

# %%
for letter in bg_alphabet:
    os.makedirs('./data/' + letter)

# %%
pwd
# Out:
# '/home/avgustina/personal/AICourse/Machine Learning/Project/Final Project/Project'

# %% [markdown]
# ### Populating the folders ###

# %%
video_folders = sorted(os.listdir('./videos'))

# %%
video_folders
# Out:
# ['vid1', 'vid2', 'vid3', 'vid3.2', 'vid3.3', 'vid4', 'vid5', 'vid6']

# %% [markdown]
# A lot of videos start off with the person positioning their hand on screen before doing the sign - that's a lot of frames that would end up wrongly labelled. I mostly cut those parts with video editing tools, however, for some, I use video_snippets, which tell from which second to which second is the actual sign.

# %%
video_snippets = {
    'A': {'vid1': (1, 7), 'vid4': (1, 10)},
    'B': {'vid1': (0, 7), 'vid4': (1 ,7)},
    'V': {'vid1': (1, 6), 'vid4': (1 ,8)},
    'G': {'vid1': (1, 7), 'vid4': (1, 9)},
    'D': {'vid1': (2, 8), 'vid4': (1, 9)},
    'E': {'vid1': (2, 7), 'vid4': (2, 8)},
    'J': {'vid1': (1, 7), 'vid4': (1, 7)},
    'Z': {'vid1': (1, 7), 'vid4': (1, 7)},
    'I': {'vid1': (1, 7), 'vid4': (1, 7)},
    'Ik': {'vid1': (1, 18), 'vid4': (1, 5)},
    'K': {'vid1': (1, 7), 'vid4': (1, 8)},
    'L': {'vid1': (2, 5), 'vid4': (1, 8)},
    'M': {'vid1': (1, 7), 'vid4': (1, 9)},
    'N': {'vid1': (1, 7), 'vid4': (1, 8)},
    'O': {'vid1': (1, 7), 'vid4': (1, 8)},
    'P': {'vid1': (1, 6), 'vid4': (1, 8)},
    'R': {'vid1': (1, 5), 'vid4': (1, 10)},
    'S': {'vid1': (2, 8), 'vid4': (1, 9)},
    'T': {'vid1': (6, 11), 'vid4': (2, 8)},
    'U': {'vid1': (1, 7), 'vid4': (1, 8)},
    'F': {'vid1': (1, 7), 'vid4': (1, 8)},
    'H': {'vid1': (3, 9), 'vid4': (3, 8)},
    'C': {'vid1': (1, 8), 'vid4': (1, 8)},
    'CH': {'vid1': (1, 8), 'vid4': (1, 8)},
    'SH': {'vid1': (2, 8), 'vid4': (1, 8)},
    'SHt': {'vid1': (2, 10)}, 
    'Y': {'vid1': (2, 7), 'vid4': (1, 8)},
    'Yrm': {'vid1': (2, 12)}, 
    'YU': {'vid1': (0, 10), 'vid4': (1, 8)},
    'YA': {'vid1': (2, 8), 'vid4': (1, 8)},
}

# %%
def convert_sec_to_frames(vidcap, video_snippet):
    from_seconds, to_seconds = video_snippet
    fps = vidcap.get(cv2.CAP_PROP_FPS)
    from_frame = int(fps * from_seconds)
    to_frame = int(fps * to_seconds)
    return from_frame, to_frame

def get_frames_from_video(video_folder_name, letter, target_path, frequency, video_snippet, file_extension = 'MOV'):  
    video_path = './videos/' + video_folder_name + '/'+ letter + '.' + file_extension
    vidcap = cv2.VideoCapture(video_path)
    
    # Check if valid path
    if not vidcap.isOpened():
        print(f"Error: Problem with opening video at path: {video_path}")
        return

    if video_snippet != None:
        from_frame, to_frame = convert_sec_to_frames(vidcap, video_snippet)
        # Move vidcap to that frame
        if from_frame: vidcap.set(cv2.CAP_PROP_POS_FRAMES, from_frame)
    else:
        from_frame, to_frame = 0, vidcap.get(cv2.CAP_PROP_FRAME_COUNT)

    # Start reading frames
    success, image = vidcap.read()
    count = from_frame or 0
    pic_num = 0
    frames_folder_path = f'{target_path}/{video_folder_name}'
    os.makedirs(f'{target_path}/{video_folder_name}')
    while success and (to_frame and count <= to_frame):
      if (count % frequency == 0): 
          cv2.imwrite(f'{frames_folder_path}/{video_folder_name}{pic_num}.jpg', image)     # save frame as JPEG file
          pic_num += 1
          # print('Saved a new frame: ', pic_num)
          success, image = vidcap.read()
      success = vidcap.grab()
      count += 1
    print (f'Extracted {pic_num} frames from {video_path}')
    vidcap.release()

# %%
for video_folder_name in video_folders:
    # for letter_video in os.listdir(f'./videos/{video_folder_name}'):
    extension = os.listdir(f'./videos/{video_folder_name}')[0].split('.')[1]
    
    for letter in bg_alphabet:
        # get snippet if such
        if video_folder_name in video_snippets[letter]:
            snippet = video_snippets[letter][video_folder_name]
        else:
            snippet = None
        # print (extension)
        get_frames_from_video(
            video_folder_name, 
            letter,
            './data/' + letter,
            FREQ,
            snippet,
            extension
        )
# Out:
# Extracted 37 frames from ./videos/vid1/A.MOV
# Extracted 36 frames from ./videos/vid1/B.MOV
# Extracted 31 frames from ./videos/vid1/V.MOV
# Extracted 37 frames from ./videos/vid1/G.MOV
# Extracted 37 frames from ./videos/vid1/D.MOV
# Extracted 31 frames from ./videos/vid1/E.MOV
# Extracted 37 frames from ./videos/vid1/J.MOV
# Extracted 37 frames from ./videos/vid1/Z.MOV
# Extracted 37 frames from ./videos/vid1/I.MOV
# Extracted 102 frames from ./videos/vid1/Ik.MOV
# Extracted 37 frames from ./videos/vid1/K.MOV
# Extracted 19 frames from ./videos/vid1/L.MOV
# Extracted 37 frames from ./videos/vid1/M.MOV
# Extracted 37 frames from ./videos/vid1/N.MOV
# Extracted 37 frames from ./videos/vid1/O.MOV
# Extracted 31 frames from ./videos/vid1/P.MOV
# Extracted 25 frames from ./videos/vid1/R.MOV
# Extracted 37 frames from ./videos/vid1/S.MOV
# Extracted 31 frames from ./videos/vid1/T.MOV
# Extracted 37 frames from ./videos/vid1/U.MOV
# Extracted 37 frames from ./videos/vid1/F.MOV
# Extracted 37 frames from ./videos/vid1/H.MOV
# Extracted 43 frames from ./videos/vid1/C.MOV
# Extracted 43 frames from ./videos/vid1/CH.MOV
# Extracted 37 frames from ./videos/vid1/SH.MOV
# Extracted 48 frames from ./videos/vid1/SHt.MOV
# Extracted 31 frames from ./videos/vid1/Y.MOV
# Extracted 61 frames from ./videos/vid1/Yrm.MOV
# Extracted 59 frames from ./videos/vid1/YU.MOV
# Extracted 37 frames from ./videos/vid1/YA.MOV
# Extracted 24 frames from ./videos/vid2/A.MOV
# Extracted 53 frames from ./videos/vid2/B.MOV
# Extracted 52 frames from ./videos/vid2/V.MOV
# Extracted 50 frames from ./videos/vid2/G.MOV
# Extracted 65 frames from ./videos/vid2/D.MOV
# Extracted 49 frames from ./videos/vid2/E.MOV
# Extracted 54 frames from ./videos/vid2/J.MOV
# Extracted 53 frames from ./videos/vid2/Z.MOV
# Extracted 52 frames from ./videos/vid2/I.MOV
# Extracted 71 frames from ./videos/vid2/Ik.MOV
# Extracted 51 frames from ./videos/vid2/K.MOV
# Extracted 51 frames from ./videos/vid2/L.MOV
# Extracted 34 frames from ./videos/vid2/M.MOV
# Extracted 48 frames from ./videos/vid2/N.MOV
# Extracted 49 frames from ./videos/vid2/O.MOV
# Extracted 45 frames from ./videos/vid2/P.MOV
# Extracted 69 frames from ./videos/vid2/R.MOV
# Extracted 46 frames from ./videos/vid2/S.MOV
# Extracted 43 frames from ./videos/vid2/T.MOV
# Extracted 58 frames from ./videos/vid2/U.MOV
# Extracted 67 frames from ./videos/vid2/F.MOV
# Extracted 51 frames from ./videos/vid2/H.MOV
# Extracted 52 frames from ./videos/vid2/C.MOV
# Extracted 52 frames from ./videos/vid2/CH.MOV
# Extracted 45 frames from ./videos/vid2/SH.MOV
# Extracted 78 frames from ./videos/vid2/SHt.MOV
# Extracted 56 frames from ./videos/vid2/Y.MOV
# Extracted 99 frames from ./videos/vid2/Yrm.MOV
# Extracted 56 frames from ./videos/vid2/YU.MOV
# Extracted 57 frames from ./videos/vid2/YA.MOV
# Extracted 17 frames from ./videos/vid3/A.mp4
# Extracted 16 frames from ./videos/vid3/B.mp4
# Extracted 27 frames from ./videos/vid3/V.mp4
# Extracted 21 frames from ./videos/vid3/G.mp4
# Extracted 8 frames from ./videos/vid3/D.mp4
# Error: Problem with opening video at path: ./videos/vid3/E.mp4
# Extracted 15 frames from ./videos/vid3/J.mp4
# Error: Problem with opening video at path: ./videos/vid3/Z.mp4
# Extracted 19 frames from ./videos/vid3/I.mp4
# Extracted 6 frames from ./videos/vid3/Ik.mp4
# Extracted 6 frames from ./videos/vid3/K.mp4
# Extracted 18 frames from ./videos/vid3/L.mp4
# Extracted 23 frames from ./videos/vid3/M.mp4
# Extracted 17 frames from ./videos/vid3/N.mp4
# Extracted 26 frames from ./videos/vid3/O.mp4
# Extracted 27 frames from ./videos/vid3/P.mp4
# Extracted 27 frames from ./videos/vid3/R.mp4
# Extracted 23 frames from ./videos/vid3/S.mp4
# Extracted 24 frames from ./videos/vid3/T.mp4
# Extracted 29 frames from ./videos/vid3/U.mp4
# Extracted 18 frames from ./videos/vid3/F.mp4
# Extracted 28 frames from ./videos/vid3/H.mp4
# Error: Problem with opening video at path: ./videos/vid3/C.mp4
# Extracted 21 frames from ./videos/vid3/CH.mp4
# Extracted 32 frames from ./videos/vid3/SH.mp4
# Extracted 6 frames from ./videos/vid3/SHt.mp4
# Error: Problem with opening video at path: ./videos/vid3/Y.mp4
# Extracted 6 frames from ./videos/vid3/Yrm.mp4
# Extracted 31 frames from ./videos/vid3/YU.mp4
# Extracted 22 frames from ./videos/vid3/YA.mp4
# Error: Problem with opening video at path: ./videos/vid3.2/A.mov
# Error: Problem with opening video at path: ./videos/vid3.2/B.mov
# Error: Problem with opening video at path: ./videos/vid3.2/V.mov
# Error: Problem with opening video at path: ./videos/vid3.2/G.mov
# Error: Problem with opening video at path: ./videos/vid3.2/D.mov
# Error: Problem with opening video at path: ./videos/vid3.2/E.mov
# Error: Problem with opening video at path: ./videos/vid3.2/J.mov
# Error: Problem with opening video at path: ./videos/vid3.2/Z.mov
# Error: Problem with opening video at path: ./videos/vid3.2/I.mov
# Error: Problem with opening video at path: ./videos/vid3.2/Ik.mov
# Error: Problem with opening video at path: ./videos/vid3.2/K.mov
# Error: Problem with opening video at path: ./videos/vid3.2/L.mov
# Error: Problem with opening video at path: ./videos/vid3.2/M.mov
# Error: Problem with opening video at path: ./videos/vid3.2/N.mov
# Error: Problem with opening video at path: ./videos/vid3.2/O.mov
# Error: Problem with opening video at path: ./videos/vid3.2/P.mov
# Error: Problem with opening video at path: ./videos/vid3.2/R.mov
# Error: Problem with opening video at path: ./videos/vid3.2/S.mov
# Error: Problem with opening video at path: ./videos/vid3.2/T.mov
# Error: Problem with opening video at path: ./videos/vid3.2/U.mov
# Error: Problem with opening video at path: ./videos/vid3.2/F.mov
# Error: Problem with opening video at path: ./videos/vid3.2/H.mov
# Error: Problem with opening video at path: ./videos/vid3.2/C.mov
# Error: Problem with opening video at path: ./videos/vid3.2/CH.mov
# Error: Problem with opening video at path: ./videos/vid3.2/SH.mov
# Extracted 10 frames from ./videos/vid3.2/SHt.mov
# Error: Problem with opening video at path: ./videos/vid3.2/Y.mov
# Extracted 6 frames from ./videos/vid3.2/Yrm.mov
# Error: Problem with opening video at path: ./videos/vid3.2/YU.mov
# Error: Problem with opening video at path: ./videos/vid3.2/YA.mov
# Error: Problem with opening video at path: ./videos/vid3.3/A.mov
# Error: Problem with opening video at path: ./videos/vid3.3/B.mov
# Error: Problem with opening video at path: ./videos/vid3.3/V.mov
# Error: Problem with opening video at path: ./videos/vid3.3/G.mov
# Error: Problem with opening video at path: ./videos/vid3.3/D.mov
# Error: Problem with opening video at path: ./videos/vid3.3/E.mov
# Error: Problem with opening video at path: ./videos/vid3.3/J.mov
# Error: Problem with opening video at path: ./videos/vid3.3/Z.mov
# Error: Problem with opening video at path: ./videos/vid3.3/I.mov
# Error: Problem with opening video at path: ./videos/vid3.3/Ik.mov
# Error: Problem with opening video at path: ./videos/vid3.3/K.mov
# Error: Problem with opening video at path: ./videos/vid3.3/L.mov
# Error: Problem with opening video at path: ./videos/vid3.3/M.mov
# Error: Problem with opening video at path: ./videos/vid3.3/N.mov
# Error: Problem with opening video at path: ./videos/vid3.3/O.mov
# Error: Problem with opening video at path: ./videos/vid3.3/P.mov
# Error: Problem with opening video at path: ./videos/vid3.3/R.mov
# Error: Problem with opening video at path: ./videos/vid3.3/S.mov
# Error: Problem with opening video at path: ./videos/vid3.3/T.mov
# Error: Problem with opening video at path: ./videos/vid3.3/U.mov
# Error: Problem with opening video at path: ./videos/vid3.3/F.mov
# Error: Problem with opening video at path: ./videos/vid3.3/H.mov
# Error: Problem with opening video at path: ./videos/vid3.3/C.mov
# Error: Problem with opening video at path: ./videos/vid3.3/CH.mov
# Error: Problem with opening video at path: ./videos/vid3.3/SH.mov
# Extracted 6 frames from ./videos/vid3.3/SHt.mov
# Error: Problem with opening video at path: ./videos/vid3.3/Y.mov
# Extracted 7 frames from ./videos/vid3.3/Yrm.mov
# Error: Problem with opening video at path: ./videos/vid3.3/YU.mov
# Error: Problem with opening video at path: ./videos/vid3.3/YA.mov
# Extracted 52 frames from ./videos/vid4/A.mov
# Extracted 35 frames from ./videos/vid4/B.mov
# Extracted 42 frames from ./videos/vid4/V.mov
# Extracted 48 frames from ./videos/vid4/G.mov
# Extracted 43 frames from ./videos/vid4/D.mov
# Extracted 36 frames from ./videos/vid4/E.mov
# Extracted 36 frames from ./videos/vid4/J.mov
# Extracted 36 frames from ./videos/vid4/Z.mov
# Extracted 36 frames from ./videos/vid4/I.mov
# Extracted 24 frames from ./videos/vid4/Ik.mov
# Extracted 42 frames from ./videos/vid4/K.mov
# Extracted 42 frames from ./videos/vid4/L.mov
# Extracted 43 frames from ./videos/vid4/M.mov
# Extracted 42 frames from ./videos/vid4/N.mov
# Extracted 42 frames from ./videos/vid4/O.mov
# Extracted 42 frames from ./videos/vid4/P.mov
# Extracted 54 frames from ./videos/vid4/R.mov
# Extracted 45 frames from ./videos/vid4/S.mov
# Extracted 36 frames from ./videos/vid4/T.mov
# Extracted 42 frames from ./videos/vid4/U.mov
# Extracted 42 frames from ./videos/vid4/F.mov
# Extracted 30 frames from ./videos/vid4/H.mov
# Extracted 42 frames from ./videos/vid4/C.mov
# Extracted 42 frames from ./videos/vid4/CH.mov
# Extracted 42 frames from ./videos/vid4/SH.mov
# Extracted 23 frames from ./videos/vid4/SHt.mov
# Extracted 43 frames from ./videos/vid4/Y.mov
# Extracted 31 frames from ./videos/vid4/Yrm.mov
# Extracted 42 frames from ./videos/vid4/YU.mov
# Extracted 42 frames from ./videos/vid4/YA.mov
# Extracted 6 frames from ./videos/vid5/A.mp4
# Extracted 13 frames from ./videos/vid5/B.mp4
# Extracted 8 frames from ./videos/vid5/V.mp4
# Extracted 8 frames from ./videos/vid5/G.mp4
# Extracted 8 frames from ./videos/vid5/D.mp4
# Extracted 5 frames from ./videos/vid5/E.mp4
# Extracted 6 frames from ./videos/vid5/J.mp4
# Extracted 6 frames from ./videos/vid5/Z.mp4
# Extracted 8 frames from ./videos/vid5/I.mp4
# Extracted 6 frames from ./videos/vid5/Ik.mp4
# Extracted 7 frames from ./videos/vid5/K.mp4
# Extracted 5 frames from ./videos/vid5/L.mp4
# Extracted 6 frames from ./videos/vid5/M.mp4
# Extracted 6 frames from ./videos/vid5/N.mp4
# Extracted 7 frames from ./videos/vid5/O.mp4
# Extracted 5 frames from ./videos/vid5/P.mp4
# Extracted 5 frames from ./videos/vid5/R.mp4
# Extracted 9 frames from ./videos/vid5/S.mp4
# Extracted 7 frames from ./videos/vid5/T.mp4
# Extracted 10 frames from ./videos/vid5/U.mp4
# Extracted 11 frames from ./videos/vid5/F.mp4
# Extracted 7 frames from ./videos/vid5/H.mp4
# Extracted 6 frames from ./videos/vid5/C.mp4
# Extracted 11 frames from ./videos/vid5/CH.mp4
# Extracted 6 frames from ./videos/vid5/SH.mp4
# Extracted 6 frames from ./videos/vid5/SHt.mp4
# Error: Problem with opening video at path: ./videos/vid5/Y.mp4
# Extracted 13 frames from ./videos/vid5/Yrm.mp4
# Extracted 8 frames from ./videos/vid5/YU.mp4
# Extracted 12 frames from ./videos/vid5/YA.mp4
# Extracted 6 frames from ./videos/vid6/A.mp4
# Extracted 6 frames from ./videos/vid6/B.mp4
# Extracted 5 frames from ./videos/vid6/V.mp4
# Extracted 8 frames from ./videos/vid6/G.mp4
# Extracted 10 frames from ./videos/vid6/D.mp4
# Extracted 11 frames from ./videos/vid6/E.mp4
# Error: Problem with opening video at path: ./videos/vid6/J.mp4
# Extracted 7 frames from ./videos/vid6/Z.mp4
# Extracted 7 frames from ./videos/vid6/I.mp4
# Extracted 20 frames from ./videos/vid6/Ik.mp4
# Extracted 13 frames from ./videos/vid6/K.mp4
# Extracted 9 frames from ./videos/vid6/L.mp4
# Extracted 9 frames from ./videos/vid6/M.mp4
# Extracted 12 frames from ./videos/vid6/N.mp4
# Extracted 11 frames from ./videos/vid6/O.mp4
# Extracted 11 frames from ./videos/vid6/P.mp4
# Extracted 7 frames from ./videos/vid6/R.mp4
# Extracted 13 frames from ./videos/vid6/S.mp4
# Extracted 6 frames from ./videos/vid6/T.mp4
# Extracted 9 frames from ./videos/vid6/U.mp4
# Extracted 14 frames from ./videos/vid6/F.mp4
# Extracted 7 frames from ./videos/vid6/H.mp4
# Extracted 9 frames from ./videos/vid6/C.mp4
# Extracted 10 frames from ./videos/vid6/CH.mp4
# Extracted 11 frames from ./videos/vid6/SH.mp4
# Extracted 9 frames from ./videos/vid6/SHt.mp4
# Extracted 12 frames from ./videos/vid6/Y.mp4
# Extracted 17 frames from ./videos/vid6/Yrm.mp4
# Extracted 7 frames from ./videos/vid6/YU.mp4
# Extracted 11 frames from ./videos/vid6/YA.mp4

# %%
os.system("tree -d")
# Out:
# .
# ├── data
# │   ├── A
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── B
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── C
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── CH
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── D
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── E
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── F
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   ���   └── vid6
# │   ├── G
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── H
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── I
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── Ik
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── J
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   └── vid5
# │   ├── K
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── L
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ���── vid5
# │   │   └── vid6
# │   ├── M
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── N
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── O
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── P
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── R
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── S
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── SH
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── SHt
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid3.2
# │   │   ├── vid3.3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── T
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── U
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │��  │   └── vid6
# │   ├── V
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── Y
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid4
# │   │   └── vid6
# │   ├── YA
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── Yrm
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid3.2
# │   │   ├── vid3.3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── YU
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   └── Z
# │       ├── vid1
# │       ├── vid2
# │       ├── vid4
# │       ├── vid5
# │       └── vid6
# ├── data1
# │   ├── A
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── B
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── C
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   └── vid4
# │   ├── CH
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── D
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── E
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   └── vid4
# │   ├── F
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── G
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── H
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── I
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── Ik
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── J
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── K
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── L
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── M
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── N
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── O
# │   ��   ├── vid1
# │   │   ├── vid2
# │   │   ��── vid3
# │   │   └── vid4
# │   ├── P
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── R
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── S
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── SH
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── SHt
# │   │   ├── vid1
# │   │ �� ├── vid2
# │   │   ├── vid3
# │   │   ├── vid3.2
# │   │   ├── vid3.3
# │   │   └── vid4
# │   ├── T
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── U
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── V
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── Y
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   └── vid4
# │   ├── YA
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   ├── Yrm
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid3.2
# │   │   ├── vid3.3
# │   │   └── vid4
# │   ├── YU
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   └── vid4
# │   └── Z
# │       ├── vid1
# │       ├── vid2
# │       └── vid4
# ├── data2
# │   ├── A
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── B
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── C
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── CH
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── D
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── E
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── F
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── G
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── H
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── I
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── Ik
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── J
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   └── vid5
# │   ├── K
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── L
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── M
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── N
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── O
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── P
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   ���── vid6
# │   ├── R
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── S
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── SH
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── SHt
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   ��   ├── vid3.2
# │   │   ├── vid3.3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── T
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── U
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── V
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── Y
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid4
# │   │   └── vid6
# │   ├── YA
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── Yrm
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid3.2
# │   │   ├── vid3.3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   ├── YU
# │   │   ├── vid1
# │   │   ├── vid2
# │   │   ├── vid3
# │   │   ├── vid4
# │   │   ├── vid5
# │   │   └── vid6
# │   └── Z
# │       ├── vid1
# │       ├── vid2
# │       ├── vid4
# │       ├── vid5
# │       └── vid6
# ├── Drafts
# ├── test
# └── videos
#     ├── vid1
#     ├── vid2
#     ├── vid3
#     ├── vid3.2
#     ├── vid3.3
#     ├── vid4
#     ├── vid5
#     └── vid6
#
# 580 directories
# 0
